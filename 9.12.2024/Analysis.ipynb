# %%
import sys
import os

# Add the parent directory to the Python path
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), os.pardir)))

# %%
# %matplotlib widget

# %%
import numpy as np

# %%
import Imaging.Tools as tls
import Imaging.Estimators as es

# %%
data = np.load('time_delay_2d_np4.np.npy')

# %%
data.shape
# Out:
# (4, 133, 500)

# %%
for i in range(1, data.shape[0], 2): #reverse every other row because of the scanning procedure we followed
    data[i] = data[i][::-1]

# %%
bin_width = 10e-12

# %%
tls.hist_analyser(data)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
one_D_plot = tls.plot_1D(data[0], 10e-12)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
two_D_plot = tls.plot_2D(data, 10e-12, (14, 1.5))
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
data2 = np.load('time_delay_2d_np3.np.npy')
for i in range(1, data2.shape[0], 2): #reverse every other row because of the scanning procedure we followed
    data2[i] = data2[i][::-1]

# %%
tls.hist_analyser(data2)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
one_D_plot2 = tls.plot_1D(data2[3], bin_width)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
two_D_plot2 = tls.plot_2D(data2[:,:-6,:], bin_width, (6, 4), estimator=es.gaus_mle)
# Out:
# e:\Virtual Environments\Projects\Time of Flight Imaging\Imaging\Tools.py:57: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig = plt.figure()
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
